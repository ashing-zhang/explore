# %% [markdown]
# # Hotel RL Analysis
#
# Run training and evaluation from the `rl/` directory:
#
# - `python -m training.train_ppo`
# - `python -m training.train_sac`
# - `python -m evaluation.evaluate`

# %%
from pathlib import Path
report = Path(__file__).resolve().parents[1] / 'evaluation_report.html'
report
